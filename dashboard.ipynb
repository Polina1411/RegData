# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=maplibre/dashboard.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/maplibre/dashboard.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/leafmap/HEAD)
#
# **Create a Dashboard**

# %%
# %pip install --upgrade pip setuptools wheel
# %pip install folium ipywidgets ipyleaflet
# Out:
# ...
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.44.0
#     Uninstalling wheel-0.44.0:
#       Successfully uninstalled wheel-0.44.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...

# %%
# %pip uninstall leafmap -y
# Out:
# WARNING: Skipping leafmap as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "leafmap<0.50" --no-deps
# %pip install folium ipywidgets ipyleaflet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 574.5/574.5 kB 755.6 kB/s  0:00:00m-:--:--
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scooby
# Out:
# ...
#   Using cached scooby-0.11.0-py3-none-any.whl.metadata (15 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# leafmap 0.49.3 requires anywidget, which is not installed.
# leafmap 0.49.3 requires bqplot, which is not installed.
# leafmap 0.49.3 requires duckdb, which is not installed.
# leafmap 0.49.3 requires gdown, which is not installed.
# leafmap 0.49.3 requires geojson, which is not installed.
# leafmap 0.49.3 requires geopandas, which is not installed.
# leafmap 0.49.3 requires ipyevents, which is not installed.
# leafmap 0.49.3 requires ipyfilechooser, which is not installed.
# leafmap 0.49.3 requires ipyvuetify, which is not installed.
# leafmap 0.49.3 requires maplibre, which is not installed.
# leafmap 0.49.3 requires pystac-client, which is not installed.
# leafmap 0.49.3 requires python-box, which is not installed.
# ...

# %%
# %pip install anywidget bqplot gdown geojson ipyevents ipyfilechooser python-box whiteboxgui
# Out:
# ...
#   Using cached anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached bqplot-0.12.45-py2.py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached ipyevents-2.0.4-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached python_box-7.3.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.0 kB)
# ...
#   Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached psygnal-0.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 626.9 kB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 646.8 kB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 576.0/576.0 kB 710.8 kB/s  0:00:00m-:--:--
# ...

# %%
# %pip install maplibre pystac-client ipyvuetify
# Out:
# ...
#   Using cached maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 689.5 kB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 689.2 kB/s  0:00:09 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 675.6 kB/s  0:00:03 eta 0:00:01
# ...
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [ipyvuetify]7 [ipyvuetify]nt]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %pip install --upgrade pandas scipy matplotlib
# Out:
#   Cell In[2], line 1
#     python -m pip install --upgrade pip setuptools wheel
#               ^
# SyntaxError: invalid syntax

# %%
import leafmap.maplibregl as leafmap
import ipywidgets as widgets
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
tw = leafmap.TabWidget(
    title="Dashboard",
    tabs=("Home", "Map", "Settings"),
    icons=("mdi-home", "mdi-map", "mdi-cog"),
    show_panel_titles=False,
)

# Customize dialog
tw.set_help_title("About this dashboard")
tw.set_help_content(
    widgets.HTML(
        """
      <p><b>Shortcuts</b></p>
      <ul>
        <li>1 / 2 / 3 — switch tabs</li>
        <li>R — refresh</li>
        <li>? — help</li>
      </ul>
    """
    )
)

m = leafmap.Map(
    projection="globe", style="liberty", sidebar_visible=True, height="800px"
)
m.create_container()

home_tab = widgets.HTML(
    """
    <h1>Welcome to the Leafmap Visualization Dashboard</h1>
    <p>This is the home tab.</p>
    <img src="https://assets.gishub.org/images/geog-312.png" width="100%">
    """
)

settings_tab = widgets.HTML(
    """
    <h1>Settings</h1>
    <p>This is the settings tab.</p>
    """
)

tw.set_tab_content(0, home_tab)
tw.set_tab_content(1, m.container)
tw.set_tab_content(2, settings_tab)

display(tw.widget)

# %% [markdown]
# ![](https://github.com/user-attachments/assets/f98d9261-650f-4e53-b8d0-f35a3a7e875a)
